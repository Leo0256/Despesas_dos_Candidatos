# %% [markdown]
# # Gráfico das Despesas Eleitorais de 2018
# ---

# %% [markdown]
# ### Título Pequeno

# %%
import pandas as pd
low_memory=False
import matplotlib.pyplot as plt


# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

filename = r"C:\Users\yggdr\Downloads\Fatec\Grafico_das_Despesas_Eleitorais\data\prestacao_contas_anual_partidaria_2018\despesa_anual_2018_BRASIL.csv"
df = pd.read_csv(filename, delimiter=";",encoding="Latin-1",error_bad_lines=False)

#data = pd.read_csv(filename, delimiter=";",encoding="Latin-1",error_bad_lines=False,
#                usecols=["NM_MUNICIPIO","SG_PARTIDO","NM_PARTIDO","DS_TP_DOCUMENTO","DS_TP_FORNECEDOR",
#                        "NM_FORNECEDOR","DS_GASTO","VR_GASTO","VR_GASTO","VR_PAGAMENTO","VR_DOCUMENTO"])

#data.info()

'''
6 - NM_MUNICIPIO
9 - SG_PARTIDO
10 - NM_PARTIDO
12 - DS_TP_DOCUMENTO
17 - DS_TP_FORNECEDOR
19 - NM_FORNECEDOR
20 - DS_GASTO
22 - VR_GASTO
23 - VR_PAGAMENTO
24 - VR_DOCUMENTO
'''
# Out:
# '\n6 - NM_MUNICIPIO\n9 - SG_PARTIDO\n10 - NM_PARTIDO\n12 - DS_TP_DOCUMENTO\n17 - DS_TP_FORNECEDOR\n19 - NM_FORNECEDOR\n20 - DS_GASTO\n22 - VR_GASTO\n23 - VR_PAGAMENTO\n24 - VR_DOCUMENTO\n'

# %%
#data.NM_MUNICIPIO[data.NM_MUNICIPIO == "#NULO#"] == ""
df.sample()
# Out:
#         DT_GERACAO HH_GERACAO  CD_TP_ESFERA_PARTIDARIA  \
# 197112  24/10/2020   15:36:58                        2
#
#        DS_TP_ESPERA_PARTIDARIA SG_UF CD_MUNICIPIO NM_MUNICIPIO NR_ZONA  \
# 197112                ESTADUAL    MG       #NULO#       #NULO#  #NULO#
#
#         NR_CNPJ_PRESTADOR_CONTA SG_PARTIDO       NM_PARTIDO CD_TP_DOCUMENTO  \
# 197112            8691904000112         PL  PARTIDO LIBERAL               2
#
#          DS_TP_DOCUMENTO NR_DOCUMENTO AA_AIDF     NR_AIDF CD_TP_FORNECEDOR  \
# 197112  DOCUMENTO FISCAL  2017/128447    2017  2017128447                J
#
#        DS_TP_FORNECEDOR NR_CPF_CNPJ_FORNECEDOR                 NM_FORNECEDOR  \
# 197112  PESSOA JURÍDICA         02059753000106  EMIVE PATRULHA 24 HORAS LTDA
#
#                              DS_GASTO DT_PAGAMENTO VR_GASTO VR_PAGAMENTO  \
# 197112  TRIBUTOS - TAXAS - ORDINÁRIAS   31/12/2017    15,15        15,15
#
#        VR_DOCUMENTO
# 197112       325,63

# %%
df[["DS_TP_FORNECEDOR","NM_FORNECEDOR"]].tail()
# Out:
#        DS_TP_FORNECEDOR        NM_FORNECEDOR
# 492070  PESSOA JURÍDICA  BANCO DO BRASIL S/A
# 492071  PESSOA JURÍDICA  BANCO DO BRASIL S/A
# 492072  PESSOA JURÍDICA  BANCO DO BRASIL S/A
# 492073    PESSOA FÍSICA    MAYSA DIAS LUCENA
# 492074  PESSOA JURÍDICA  BANCO DO BRASIL S/A

# %%
df.sample(5)
# Out:
#         DT_GERACAO HH_GERACAO  CD_TP_ESFERA_PARTIDARIA  \
# 115189  24/10/2020   15:36:58                        0
# 440526  24/10/2020   15:36:58                        4
# 44646   24/10/2020   15:36:58                        0
# 273512  24/10/2020   15:36:58                        2
# 423112  24/10/2020   15:36:58                        4
#
#        DS_TP_ESPERA_PARTIDARIA SG_UF CD_MUNICIPIO   NM_MUNICIPIO NR_ZONA  \
# 115189                NACIONAL    BR       #NULO#         #NULO#  #NULO#
# 440526               MUNICIPAL    RS         8791        PELOTAS  #NULO#
# 44646                 NACIONAL    BR       #NULO#         #NULO#  #NULO#
# 273512                ESTADUAL    RJ       #NULO#         #NULO#  #NULO#
# 423112               MUNICIPAL    RS         8525  ARROIO GRANDE  #NULO#
#
#         NR_CNPJ_PRESTADOR_CONTA SG_PARTIDO  \
# 115189           31886963000168         PV
# 440526            1317743000152        PTB
# 44646            12952205000156       PROS
# ...

# %%
float(df.loc[0, "VR_GASTO"].replace(",","."))

'''
teste = []
for x in df.VR_GASTO:
    teste.append(float(x.replace(",",".")))
'''

df[df.DS_TP_FORNECEDOR == "PESSOA JURÍDICA"].head(5)
# Out:
#    DT_GERACAO HH_GERACAO  CD_TP_ESFERA_PARTIDARIA DS_TP_ESPERA_PARTIDARIA  \
# 0  24/10/2020   15:36:58                        0                NACIONAL
# 1  24/10/2020   15:36:58                        0                NACIONAL
# 2  24/10/2020   15:36:58                        0                NACIONAL
# 3  24/10/2020   15:36:58                        0                NACIONAL
# 4  24/10/2020   15:36:58                        0                NACIONAL
#
#   SG_UF CD_MUNICIPIO NM_MUNICIPIO NR_ZONA  NR_CNPJ_PRESTADOR_CONTA SG_PARTIDO  \
# 0    BR       #NULO#       #NULO#  #NULO#           59933952000100     AVANTE
# 1    BR       #NULO#       #NULO#  #NULO#           59933952000100     AVANTE
# 2    BR       #NULO#       #NULO#  #NULO#           59933952000100     AVANTE
# 3    BR       #NULO#       #NULO#  #NULO#           59933952000100     AVANTE
# 4    BR       #NULO#       #NULO#  #NULO#           59933952000100     AVANTE
#
# ...

# %%
df[df["VR_GASTO"] in str(range(1000))].head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-387164cebfec> in <module>
# ----> 1 df[df["VR_GASTO"] in str(range(1000))].head()
#
# TypeError: 'in <string>' requires string as left operand, not Series

# %%
df.loc[0]
# Out:
# DT_GERACAO                                                        24/10/2020
# HH_GERACAO                                                          15:36:58
# CD_TP_ESFERA_PARTIDARIA                                                    0
# DS_TP_ESPERA_PARTIDARIA                                             NACIONAL
# SG_UF                                                                     BR
# CD_MUNICIPIO                                                          #NULO#
# NM_MUNICIPIO                                                          #NULO#
# NR_ZONA                                                               #NULO#
# NR_CNPJ_PRESTADOR_CONTA                                       59933952000100
# SG_PARTIDO                                                            AVANTE
# NM_PARTIDO                                                            AVANTE
# CD_TP_DOCUMENTO                                                            5
# ...
